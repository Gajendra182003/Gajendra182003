# %% [markdown]
# <a href="https://colab.research.google.com/github/Gajendra182003/Gajendra182003/blob/main/Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n=5
fact=1
for i in range(1,6):
     fact=fact*i;
     print(fact)
# Out:
# 1
# 2
# 6
# 24
# 120
